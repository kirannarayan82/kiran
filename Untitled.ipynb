# %%
import pandas as pd

# %%
mydata=pd.read_csv('/home/ramyaveerphotos/kiran/Customerprofile.csv')

# %%
campdata=pd.read_csv('/home/ramyaveerphotos/kiran/campaign.csv')

# %%
mydata['id']=campdata['CUST_ID']

# %%
mydata.columns=['CUST_ID','first_name', 'last_name', 'Gender', 'Date_of_Birth', 'country',
       'Age', 'Address', 'Occupation', 'Marital.Status', 'Geography_id',
       'email', 'Contact_Number', 'Annual.Income', 'Own.Home', 'Own.Car',
       'Own.property', 'Created_date', 'Modified_date', 'Zone_id', 'Zone_Name',
       'Region_id', 'Region_Name', 'Country_Name', 'Policy_id_sk',
       'Premium_Amount', 'Product_Name', 'Claim_Amount', 'NumOfClaims',
       'Channel_sk', 'Channel_code', 'Married_Since', 'House_tenure',
       'NoOfHomes', 'NumOfCars']

# %%
merged=pd.merge(campdata,mydata,on='CUST_ID')

# %%
frame=merged[['MARSTA_C','Date_of_Birth', 'country', 'Age', 'Occupation',
       'Marital.Status','Annual.Income', 'Own.Home', 'Own.Car', 'Own.property', 'Created_date',
       'Modified_date', 'Zone_id', 'Zone_Name', 'Region_id', 'Region_Name',
       'Country_Name', 'Policy_id_sk', 'Premium_Amount', 'Product_Name',
       'Claim_Amount', 'NumOfClaims', 'Channel_sk', 'Channel_code',
       'Married_Since', 'House_tenure', 'NoOfHomes', 'NumOfCars']]

# %%
n=10
while(n<len(frame)):
    for chunk in range(round(len(frame)/n)):
        print(frame.iloc[0:chunk,:])
        n=n+10
# Out:
# Empty DataFrame
# Columns: [MARSTA_C, Date_of_Birth, country, Age, Occupation, Marital.Status, Annual.Income, Own.Home, Own.Car, Own.property, Created_date, Modified_date, Zone_id, Zone_Name, Region_id, Region_Name, Country_Name, Policy_id_sk, Premium_Amount, Product_Name, Claim_Amount, NumOfClaims, Channel_sk, Channel_code, Married_Since, House_tenure, NoOfHomes, NumOfCars]
# Index: []
#
# [0 rows x 28 columns]
#    MARSTA_C Date_of_Birth country  Age  Occupation Marital.Status  \
# 0         1    10/05/1969  Sweden   46  MANAGEMENT        Married
#
#    Annual.Income  Own.Home  Own.Car  Own.property  ... Premium_Amount  \
# 0      634668.78         2        1             2  ...      1298606.6
#
#      Product_Name Claim_Amount NumOfClaims Channel_sk Channel_code  \
# 0  UnitGain Super   1924525.36        4.41  Channel_6          DMI
#
#   Married_Since House_tenure  NoOfHomes NumOfCars
# 0             2           21          2         2
#
# [1 rows x 28 columns]
# ...
